# %% [markdown]
# Libraries are imported

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# pandas read command is used to read the file from our directory

# %%
df = pd.read_csv("C:/Users/Pablo Escobar/Desktop/Big Data Analytics/Lab/WhereToLive/LaqnData_OxfordRd_d.csv")

# %%
df.head()
# Out:
#   Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %%
df.head()
# Out:
#   Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %%
df.columns
# Out:
# Index(['Site', 'Species', 'ReadingDateTime', 'Value', 'Units',
#        'Provisional or Ratified'],
#       dtype='object')

# %% [markdown]
# All the coumns are upper cased beacause its a good practice.

# %%
df.columns.str.upper()
# Out:
# Index(['SITE', 'SPECIES', 'READINGDATETIME', 'VALUE', 'UNITS',
#        'PROVISIONAL OR RATIFIED'],
#       dtype='object')

# %%
df.head()
# Out:
#   Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %% [markdown]
# It can be noted that column names are still lower cased. Solving this

# %%
df.columns = df.columns.str.upper()

# %%
df.head()
# Out:
#   SITE SPECIES   READINGDATETIME  VALUE   UNITS PROVISIONAL OR RATIFIED
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %% [markdown]
#     Seeing the null values

# %%
df.isnull()
# Out:
#          SITE  SPECIES  READINGDATETIME  VALUE  UNITS  PROVISIONAL OR RATIFIED
# 0       False    False            False  False  False                    False
# 1       False    False            False  False  False                    False
# 2       False    False            False  False  False                    False
# 3       False    False            False  False  False                    False
# 4       False    False            False  False  False                    False
# 5       False    False            False  False  False                    False
# 6       False    False            False  False  False                    False
# 7       False    False            False  False  False                    False
# 8       False    False            False  False  False                    False
# 9       False    False            False  False  False                    False
# 10      False    False            False  False  False                    False
# ...

# %% [markdown]
# As null values could be present anywhere in the big file. Lets track is down.

# %%
df.isnull().any()
# Out:
# SITE                       False
# SPECIES                    False
# READINGDATETIME            False
# VALUE                       True
# UNITS                      False
# PROVISIONAL OR RATIFIED    False
# dtype: bool

# %% [markdown]
# The above command shows that values column has null values.

# %%
df.isnull().any().any()
# Out:
# True

# %% [markdown]
# Counting the null values

# %%
df.isnull().sum()
# Out:
# SITE                           0
# SPECIES                        0
# READINGDATETIME                0
# VALUE                      38942
# UNITS                          0
# PROVISIONAL OR RATIFIED        0
# dtype: int64

# %% [markdown]
# values column has 38942 null values.

# %%
 df.columns.values.size
# Out:
# 6

# %%
df.isnull().sum().sum()
# Out:
# 38942

# %% [markdown]
# Filling all null values by zero.

# %%
df_with_zero = df.fillna(0)

# %%
df_with_zero.head()
# Out:
#   SITE SPECIES   READINGDATETIME  VALUE   UNITS PROVISIONAL OR RATIFIED
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %%
df_with_zero.isnull().sum()
# Out:
# SITE                       0
# SPECIES                    0
# READINGDATETIME            0
# VALUE                      0
# UNITS                      0
# PROVISIONAL OR RATIFIED    0
# dtype: int64

# %%
df['VALUE'].mean()
# Out:
# 100.10927009119106

# %%
df.head()
# Out:
#   SITE SPECIES   READINGDATETIME  VALUE   UNITS PROVISIONAL OR RATIFIED
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %%
df_fill_with_mean = df.VALUE.fillna(df['VALUE'].mean())

# %%
df_fill_with_mean.isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (140160, 6)

# %%
df.isnull().sum()
# Out:
# SITE                           0
# SPECIES                        0
# READINGDATETIME                0
# VALUE                      38942
# UNITS                          0
# PROVISIONAL OR RATIFIED        0
# dtype: int64

# %%
df.shape
# Out:
# (140160, 6)

# %%
df_drop_null = df.dropna()

# %%
df_drop_null.shape
# Out:
# (101218, 6)

# %%
df.head()
# Out:
#   SITE SPECIES   READINGDATETIME  VALUE   UNITS PROVISIONAL OR RATIFIED
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %%
df.to_csv('asd.csv')

# %%
df.head()
# Out:
#   SITE SPECIES   READINGDATETIME  VALUE   UNITS PROVISIONAL OR RATIFIED
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %%
df.tail()
# Out:
#        SITE SPECIES   READINGDATETIME  VALUE  UNITS PROVISIONAL OR RATIFIED
# 140155  WM6    PM10  31/12/2018 22:45   23.9  ug/m3                       P
# 140156  WM6    PM10  31/12/2018 23:00   22.3  ug/m3                       P
# 140157  WM6    PM10  31/12/2018 23:15   22.3  ug/m3                       P
# 140158  WM6    PM10  31/12/2018 23:30   22.3  ug/m3                       P
# 140159  WM6    PM10  31/12/2018 23:45   22.3  ug/m3                       P

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140160 entries, 0 to 140159
# Data columns (total 6 columns):
# SITE                       140160 non-null object
# SPECIES                    140160 non-null object
# READINGDATETIME            140160 non-null object
# VALUE                      101218 non-null float64
# UNITS                      140160 non-null object
# PROVISIONAL OR RATIFIED    140160 non-null object
# dtypes: float64(1), object(5)
# memory usage: 6.4+ MB

# %%
df.columns
# Out:
# Index(['SITE', 'SPECIES', 'READINGDATETIME', 'VALUE', 'UNITS',
#        'PROVISIONAL OR RATIFIED'],
#       dtype='object')

# %%
df.SITE.value_counts(dropna=False)
# Out:
# WM6    140160
# Name: SITE, dtype: int64

# %%
df.SPECIES.value_counts(dropna=False)
# Out:
# NO      35040
# NO2     35040
# NOX     35040
# PM10    35040
# Name: SPECIES, dtype: int64

# %%
df.VALUE.value_counts(dropna=False)
# Out:
# NaN           38942
#  27.60000       200
#  18.80000       190
#  20.60000       188
#  22.00000       182
#  19.20000       182
#  20.20000       181
#  25.30000       181
#  28.30000       181
#  24.30000       179
#  32.50000       176
#  26.90000       176
#  27.80000       176
#  24.10000       175
#  19.90000       173
#  22.70000       169
#  20.40000       167
#  25.70000       166
#  19.00000       166
#  25.50000       165
#  18.10000       164
#  27.40000       164
#  23.40000       163
#  31.50000       163
#  16.00000       161
#  25.00000       157
#  26.70000       157
#  30.80000       157
#  15.50000       155
#  19.70000       155
#               ...
#  436.89999        1
#  465.79999        1
#  336.79999        1
#  725.59998        1
#  581.20001        1
#  583.29999        1
#  450.20001        1
#  592.90002        1
#  654.00000        1
#  483.60001        1
#  644.40002        1
#  594.40002        1
#  508.10001        1
#  577.59998        1
# ...

# %%
df.READINGDATETIME.value_counts(dropna=False)
# Out:
# 22/08/2018 03:30    4
# 02/09/2018 18:45    4
# 07/06/2018 14:45    4
# 22/01/2018 09:00    4
# 25/06/2018 06:15    4
# 04/05/2018 05:15    4
# 06/04/2018 14:30    4
# 28/08/2018 08:30    4
# 25/12/2018 07:00    4
# 14/07/2018 00:30    4
# 13/05/2018 01:30    4
# 02/11/2018 05:00    4
# 24/05/2018 04:15    4
# 22/09/2018 17:30    4
# 28/09/2018 13:45    4
# 12/09/2018 16:30    4
# 07/09/2018 23:15    4
# 22/07/2018 21:15    4
# 30/03/2018 17:15    4
# 11/02/2018 02:45    4
# 09/05/2018 23:15    4
# 07/11/2018 18:45    4
# 01/08/2018 05:30    4
# 17/12/2018 10:30    4
# 13/09/2018 10:30    4
# 08/01/2018 21:30    4
# 26/09/2018 10:15    4
# 09/07/2018 23:00    4
# 23/05/2018 07:30    4
# 14/05/2018 14:15    4
#                    ..
# 20/08/2018 12:00    4
# 21/02/2018 20:15    4
# 21/02/2018 18:30    4
# 18/10/2018 11:15    4
# 31/10/2018 03:00    4
# 16/01/2018 02:45    4
# 20/01/2018 00:30    4
# 11/02/2018 07:15    4
# 28/10/2018 08:30    4
# 26/06/2018 03:15    4
# ...

# %%
df.['PROVISIONAL OR RATIFIED'].value_counts(dropna=False)
# Out:
#   File "<ipython-input-39-dd5078dbf3a3>", line 1
#     df.['PROVISIONAL OR RATIFIED'].value_counts(dropna=False)
#        ^
# SyntaxError: invalid syntax

# %%
df.columns

# %%
df.columns.str.strip

# %%
df.columns

# %%
dff = df.columns.str.strip

# %%
df.columns

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   site species   readingdatetime  value   units provisional_or_ratified
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %%
df.site.value_counts(dropna=False)
# Out:
# WM6    140160
# Name: site, dtype: int64

# %%
df.species.value_counts(dropna=False)
# Out:
# NO      35040
# NO2     35040
# NOX     35040
# PM10    35040
# Name: species, dtype: int64

# %%
df.readingdatetime.value_counts()
# Out:
# 22/08/2018 03:30    4
# 02/09/2018 18:45    4
# 07/06/2018 14:45    4
# 22/01/2018 09:00    4
# 25/06/2018 06:15    4
# 04/05/2018 05:15    4
# 06/04/2018 14:30    4
# 28/08/2018 08:30    4
# 25/12/2018 07:00    4
# 14/07/2018 00:30    4
# 13/05/2018 01:30    4
# 02/11/2018 05:00    4
# 24/05/2018 04:15    4
# 22/09/2018 17:30    4
# 28/09/2018 13:45    4
# 12/09/2018 16:30    4
# 07/09/2018 23:15    4
# 22/07/2018 21:15    4
# 30/03/2018 17:15    4
# 11/02/2018 02:45    4
# 09/05/2018 23:15    4
# 07/11/2018 18:45    4
# 01/08/2018 05:30    4
# 17/12/2018 10:30    4
# 13/09/2018 10:30    4
# 08/01/2018 21:30    4
# 26/09/2018 10:15    4
# 09/07/2018 23:00    4
# 23/05/2018 07:30    4
# 14/05/2018 14:15    4
#                    ..
# 20/08/2018 12:00    4
# 21/02/2018 20:15    4
# 21/02/2018 18:30    4
# 18/10/2018 11:15    4
# 31/10/2018 03:00    4
# 16/01/2018 02:45    4
# 20/01/2018 00:30    4
# 11/02/2018 07:15    4
# 28/10/2018 08:30    4
# 26/06/2018 03:15    4
# ...

# %%
df.value.value_counts(dropna=False)
# Out:
# NaN           38942
#  27.60000       200
#  18.80000       190
#  20.60000       188
#  22.00000       182
#  19.20000       182
#  20.20000       181
#  25.30000       181
#  28.30000       181
#  24.30000       179
#  32.50000       176
#  26.90000       176
#  27.80000       176
#  24.10000       175
#  19.90000       173
#  22.70000       169
#  20.40000       167
#  25.70000       166
#  19.00000       166
#  25.50000       165
#  18.10000       164
#  27.40000       164
#  23.40000       163
#  31.50000       163
#  16.00000       161
#  25.00000       157
#  26.70000       157
#  30.80000       157
#  15.50000       155
#  19.70000       155
#               ...
#  436.89999        1
#  465.79999        1
#  336.79999        1
#  725.59998        1
#  581.20001        1
#  583.29999        1
#  450.20001        1
#  592.90002        1
#  654.00000        1
#  483.60001        1
#  644.40002        1
#  594.40002        1
#  508.10001        1
#  577.59998        1
# ...

# %%
df.units.value_counts(dropna=False)
# Out:
# ug m-3             70080
# ug/m3              35040
# ug m-3 as NO2      35012
# ug m-3 as NO 2        27
# ug m -3 as NO 2        1
# Name: units, dtype: int64

# %%
df.provisional_or_ratified.value_counts(dropna=False)
# Out:
# P    115296
# R     24864
# Name: provisional_or_ratified, dtype: int64

# %%
df.describe()
# Out:
#                value
# count  101218.000000
# mean      100.109270
# std        99.123737
# min        -1.800000
# 25%        34.100000
# 50%        66.800000
# 75%       127.200000
# max      1416.199950

# %%
df.dtypes
# Out:
# site                        object
# species                     object
# readingdatetime             object
# value                      float64
# units                       object
# provisional_or_ratified     object
# dtype: object

# %%
df.head()
# Out:
#   site species   readingdatetime  value   units provisional_or_ratified
# 0  WM6      NO  01/01/2018 00:00   55.9  ug m-3                       R
# 1  WM6      NO  01/01/2018 00:15   56.4  ug m-3                       R
# 2  WM6      NO  01/01/2018 00:30   55.5  ug m-3                       R
# 3  WM6      NO  01/01/2018 00:45   69.1  ug m-3                       R
# 4  WM6      NO  01/01/2018 01:00   34.7  ug m-3                       R

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140160 entries, 0 to 140159
# Data columns (total 6 columns):
# site                       140160 non-null object
# species                    140160 non-null object
# readingdatetime            140160 non-null object
# value                      101218 non-null float64
# units                      140160 non-null object
# provisional_or_ratified    140160 non-null object
# dtypes: float64(1), object(5)
# memory usage: 6.4+ MB

# %%
df.readingdatetime = pd.to_datetime(df.readingdatetime)

# %%
df.dtypes
# Out:
# site                               object
# species                            object
# readingdatetime            datetime64[ns]
# value                             float64
# units                              object
# provisional_or_ratified            object
# dtype: object

# %%
df.head()
# Out:
#   site species     readingdatetime  value   units provisional_or_ratified
# 0  WM6      NO 2018-01-01 00:00:00   55.9  ug m-3                       R
# 1  WM6      NO 2018-01-01 00:15:00   56.4  ug m-3                       R
# 2  WM6      NO 2018-01-01 00:30:00   55.5  ug m-3                       R
# 3  WM6      NO 2018-01-01 00:45:00   69.1  ug m-3                       R
# 4  WM6      NO 2018-01-01 01:00:00   34.7  ug m-3                       R

# %%
df.tail()
# Out:
#        site species     readingdatetime  value  units provisional_or_ratified
# 140155  WM6    PM10 2018-12-31 22:45:00   23.9  ug/m3                       P
# 140156  WM6    PM10 2018-12-31 23:00:00   22.3  ug/m3                       P
# 140157  WM6    PM10 2018-12-31 23:15:00   22.3  ug/m3                       P
# 140158  WM6    PM10 2018-12-31 23:30:00   22.3  ug/m3                       P
# 140159  WM6    PM10 2018-12-31 23:45:00   22.3  ug/m3                       P

# %%
df.units.value_counts(dropna=False)
# Out:
# ug m-3             70080
# ug/m3              35040
# ug m-3 as NO2      35012
# ug m-3 as NO 2        27
# ug m -3 as NO 2        1
# Name: units, dtype: int64

# %%
df.units = 'ug/m3'

# %%
df.tail()
# Out:
#        site species     readingdatetime  value  units provisional_or_ratified
# 140155  WM6    PM10 2018-12-31 22:45:00   23.9  ug/m3                       P
# 140156  WM6    PM10 2018-12-31 23:00:00   22.3  ug/m3                       P
# 140157  WM6    PM10 2018-12-31 23:15:00   22.3  ug/m3                       P
# 140158  WM6    PM10 2018-12-31 23:30:00   22.3  ug/m3                       P
# 140159  WM6    PM10 2018-12-31 23:45:00   22.3  ug/m3                       P

# %%
df.units.value_counts(dropna=False)
# Out:
# ug/m3    140160
# Name: units, dtype: int64

# %%
df.head()
# Out:
#   site species     readingdatetime  value  units provisional_or_ratified
# 0  WM6      NO 2018-01-01 00:00:00   55.9  ug/m3                       R
# 1  WM6      NO 2018-01-01 00:15:00   56.4  ug/m3                       R
# 2  WM6      NO 2018-01-01 00:30:00   55.5  ug/m3                       R
# 3  WM6      NO 2018-01-01 00:45:00   69.1  ug/m3                       R
# 4  WM6      NO 2018-01-01 01:00:00   34.7  ug/m3                       R

# %%
df.site.value_counts(dropna=False)
# Out:
# WM6    140160
# Name: site, dtype: int64

# %%
df.species.value_counts(dropna=False)
# Out:
# NO      35040
# NO2     35040
# NOX     35040
# PM10    35040
# Name: species, dtype: int64

# %%
df.provisional_or_ratified.value_counts(dropna=False)
# Out:
# P    115296
# R     24864
# Name: provisional_or_ratified, dtype: int64

# %%
df.dtypes
# Out:
# site                               object
# species                            object
# readingdatetime            datetime64[ns]
# value                             float64
# units                              object
# provisional_or_ratified            object
# dtype: object

# %%
df.head()
# Out:
#   site species     readingdatetime  value  units provisional_or_ratified
# 0  WM6      NO 2018-01-01 00:00:00   55.9  ug/m3                       R
# 1  WM6      NO 2018-01-01 00:15:00   56.4  ug/m3                       R
# 2  WM6      NO 2018-01-01 00:30:00   55.5  ug/m3                       R
# 3  WM6      NO 2018-01-01 00:45:00   69.1  ug/m3                       R
# 4  WM6      NO 2018-01-01 01:00:00   34.7  ug/m3                       R

# %%
df.to_csv('CleanData.csv',index = False)

# %%
df.head()
# Out:
#   site species     readingdatetime  value  units provisional_or_ratified
# 0  WM6      NO 2018-01-01 00:00:00   55.9  ug/m3                       R
# 1  WM6      NO 2018-01-01 00:15:00   56.4  ug/m3                       R
# 2  WM6      NO 2018-01-01 00:30:00   55.5  ug/m3                       R
# 3  WM6      NO 2018-01-01 00:45:00   69.1  ug/m3                       R
# 4  WM6      NO 2018-01-01 01:00:00   34.7  ug/m3                       R

# %%
df.shape
# Out:
# (140160, 6)

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 140130    False
# 140131    False
# 140132    False
# 140133    False
# 140134    False
# 140135    False
# 140136    False
# 140137    False
# 140138    False
# 140139    False
# 140140    False
# 140141    False
# 140142    False
# 140143    False
# 140144    False
# 140145    False
# 140146    False
# 140147    False
# 140148    False
# 140149    False
# 140150    False
# 140151    False
# 140152    False
# 140153    False
# ...

# %%
df.loc[df.duplicated(), :]
# Out:
# Empty DataFrame
# Columns: [site, species, readingdatetime, value, units, provisional_or_ratified]
# Index: []

# %%
df.drop_duplicates()
# Out:
#        site species     readingdatetime  value  units provisional_or_ratified
# 0       WM6      NO 2018-01-01 00:00:00   55.9  ug/m3                       R
# 1       WM6      NO 2018-01-01 00:15:00   56.4  ug/m3                       R
# 2       WM6      NO 2018-01-01 00:30:00   55.5  ug/m3                       R
# 3       WM6      NO 2018-01-01 00:45:00   69.1  ug/m3                       R
# 4       WM6      NO 2018-01-01 01:00:00   34.7  ug/m3                       R
# 5       WM6      NO 2018-01-01 01:15:00   41.8  ug/m3                       R
# 6       WM6      NO 2018-01-01 01:30:00   41.8  ug/m3                       R
# 7       WM6      NO 2018-01-01 01:45:00   95.1  ug/m3                       R
# 8       WM6      NO 2018-01-01 02:00:00   93.6  ug/m3                       R
# 9       WM6      NO 2018-01-01 02:15:00   45.5  ug/m3                       R
# 10      WM6      NO 2018-01-01 02:30:00   41.8  ug/m3                       R
# ...

# %%
df.shape
# Out:
# (140160, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140160 entries, 0 to 140159
# Data columns (total 6 columns):
# site                       140160 non-null object
# species                    140160 non-null object
# readingdatetime            140160 non-null datetime64[ns]
# value                      101218 non-null float64
# units                      140160 non-null object
# provisional_or_ratified    140160 non-null object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 6.4+ MB

# %%
df.value.value_counts(dropna=False)
# Out:
# 0.00000      38945
# 27.60000       200
# 18.80000       190
# 20.60000       188
# 22.00000       182
# 19.20000       182
# 25.30000       181
# 28.30000       181
# 20.20000       181
# 24.30000       179
# 26.90000       176
# 32.50000       176
# 27.80000       176
# 24.10000       175
# 19.90000       173
# 22.70000       169
# 20.40000       167
# 19.00000       166
# 25.70000       166
# 25.50000       165
# 27.40000       164
# 18.10000       164
# 23.40000       163
# 31.50000       163
# 16.00000       161
# 25.00000       157
# 26.70000       157
# 30.80000       157
# 15.50000       155
# 19.70000       155
#              ...
# 437.70001        1
# 582.29999        1
# 581.70001        1
# 557.09998        1
# 550.20001        1
# 549.79999        1
# 318.20001        1
# 405.60001        1
# 406.39999        1
# 347.70001        1
# 371.89999        1
# 589.59998        1
# 422.29999        1
# 753.20001        1
# 290.10001        1
# 864.09998        1
# ...

# %%
df = df.fillna(0)

# %%
df.value.value_counts(dropna=False)
# Out:
# 0.00000      38945
# 27.60000       200
# 18.80000       190
# 20.60000       188
# 22.00000       182
# 19.20000       182
# 25.30000       181
# 28.30000       181
# 20.20000       181
# 24.30000       179
# 26.90000       176
# 32.50000       176
# 27.80000       176
# 24.10000       175
# 19.90000       173
# 22.70000       169
# 20.40000       167
# 19.00000       166
# 25.70000       166
# 25.50000       165
# 27.40000       164
# 18.10000       164
# 23.40000       163
# 31.50000       163
# 16.00000       161
# 25.00000       157
# 26.70000       157
# 30.80000       157
# 15.50000       155
# 19.70000       155
#              ...
# 437.70001        1
# 582.29999        1
# 581.70001        1
# 557.09998        1
# 550.20001        1
# 549.79999        1
# 318.20001        1
# 405.60001        1
# 406.39999        1
# 347.70001        1
# 371.89999        1
# 589.59998        1
# 422.29999        1
# 753.20001        1
# 290.10001        1
# 864.09998        1
# ...

# %%
df.to_csv('clean_data.csv',index=False)
